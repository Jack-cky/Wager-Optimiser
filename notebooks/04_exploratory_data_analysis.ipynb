# %%
import dtale
import pandas as pd
import sweetviz as sv

# %%
df = pd.read_parquet("../data/processed/jleague.parquet")
df.query("fold == 'train'", inplace=True)

# %%
sv.analyze(df).show_html("../data/eda/jl_eda.html")

# %%
dtale.show(df)
