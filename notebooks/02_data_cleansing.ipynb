# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Cleanse Play History

# %%
seasons = [
    "2015-2016", "2016-2017", "2017-2018", "2018-2019",
    "2019-2020", "2020-2021", "2021-2022", "2022-2023",
    "2023-2024", "2024-2025", "2025-2026",
]

dfs = []
for season in seasons:
    df = pd.read_parquet(f"../data/raw/{season}.parquet")
    df["season"] = season[-4:]
    dfs.append(df)

df = pd.concat(dfs, ignore_index=True)

# %%
# parse date and time
df["season"] = df["season"].astype(int)

df["jst"] = pd.to_datetime(df["date"], format="%d/%m/%Y %H:%M %Z", utc=True) \
    .dt.tz_convert("Asia/Tokyo")
df["date"] = df["jst"].dt.strftime("%Y-%m-%d")
df["time"] = df["jst"].dt.strftime("%H:%M")

# %%
# parse goals and results
df[["hg", "ag"]] = df["full_goal"].str.split(" - ", expand=True).astype(int)
df["res"] = np.select(
    [df["hg"] > df["ag"], df["hg"] < df["ag"]],
    ["H", "A"],
    default="D",
)
df["goals_abs_diff"] = (df["hg"] - df["ag"]).abs()

# %%
# parse handicap
df[["hcap_side", "hcap_line"]] = df["handicap"].str.split(expand=True)
df["hcap_side"] = df["hcap_side"].str[0]
df["hcap_line"] = pd.to_numeric(df["hcap_line"], errors="coerce").fillna(0)

mask = df["hcap_line"] > 0
df.loc[mask, "hcap_line"] *= -1
df.loc[mask, "hcap_side"] = df.loc[mask, "hcap_side"].map({"H": "A", "A": "H"})

# %%
# calculate handicap results
df["hcap_hg"] = df["hg"] + df["hcap_line"].where(df["hcap_side"] == "H", 0)
df["hcap_ag"] = df["ag"] + df["hcap_line"].where(df["hcap_side"] == "A", 0)
df["hcap_res"] = np.select(
    [df["hcap_hg"] > df["hcap_ag"], df["hcap_hg"] < df["hcap_ag"]],
    ["H", "A"],
    default="D",
)

mask = df["hcap_res"] == "D"
df.loc[mask, "hcap_res"] = df.loc[mask, "hcap_side"].map({"H": "A", "A": "H"})

# %% [markdown]
# #### Normalise Data

# %%
fixtures = df[[
    "season", "date", "time", "home",
    "away", "hg", "ag", "res",
    "hcap_side", "hcap_line", "hcap_res", "source",
]].sort_values(by=["date", "time"], ignore_index=True)

# %%
dfs = []
for stadium, team in enumerate(["away", "home"]):
    play = df.rename(
        columns={team: "team", f"{team[0]}g": "goals"},
    ).copy()

    play["net_goals"] = play["goals_abs_diff"].where(
        play["res"] == team[0].upper(),
        -play["goals_abs_diff"],
    )
    play["points"] = play["res"].str.lower() \
        .map({team[0]: 3, "d": 1}) \
        .fillna(0) \
        .astype(int)
    play["stadium"] = stadium

    dfs.append(play)

plays = pd.concat(dfs, ignore_index=True)

# %%
plays = plays[[
    "season", "date", "team", "goals",
    "points", "net_goals", "stadium",
]].sort_values(by=["date"], ignore_index=True)

# %%
fixtures.to_parquet("../data/interim/fixtures.parquet", index=False)
plays.to_parquet("../data/interim/plays.parquet", index=False)
